# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#import CSV file
data1 = pd.read_csv('ebolaData.csv', encoding='latin-1')
data1
# Out:
#       ID           VL  Age  Gender   DischType AbdP MuscP Fever H_ache Vomit  \
# 0   E101      8158758   23    Male        Died   No    No   Yes    Yes    No
# 1   E102        97656   43    Male        Died  Yes    No   Yes    Yes    No
# 2   E103    275363871   37  Female        Died   No    No   Yes    Yes   Yes
# 3   E104      2792376   45  Female        Died  Yes    No   Yes    Yes    No
# 4   E105       534008   42  Female        Died  Yes    No   Yes    Yes    No
# ..   ...          ...  ...     ...         ...  ...   ...   ...    ...   ...
# 95  E196  17851851143   28  Female  Discharged   No    No    No     No    No
# 96  E197  29159064946   39  Female        Died   No    No   Yes    Yes    No
# 97  E198      1594920   31    Male        Died  Yes    No   Yes    Yes    No
# 98  E199  15903231522   39  Female        Died   No    No   Yes    Yes    No
# 99  E200   5623146991   26  Female        Died  Yes    No   Yes     No   Yes
#
#    Diarrh Weak Dizzi
# 0     Yes   No   Yes
# ...

# %%
#select Gender

# %%
data2 = data1[data1.Gender=='Female']

# %%
data2.head()
# Out:
#      ID           VL  Age  Gender DischType AbdP MuscP Fever H_ache Vomit  \
# 2  E103    275363871   37  Female      Died   No    No   Yes    Yes   Yes
# 3  E104      2792376   45  Female      Died  Yes    No   Yes    Yes    No
# 4  E105       534008   42  Female      Died  Yes    No   Yes    Yes    No
# 5  E106       226320   22  Female      Died   No    No   Yes     No    No
# 7  E108  36563459048   45  Female      Died   No    No   Yes    Yes    No
#
#   Diarrh Weak Dizzi
# 2     No  Yes   Yes
# 3    Yes  Yes   Yes
# 4    Yes  Yes   Yes
# 5    Yes  Yes    No
# 7     No  Yes    No

# %%
data3 = data2[data2.DischType=="Died"]

# %%
data3.head()
# Out:
#      ID           VL  Age  Gender DischType AbdP MuscP Fever H_ache Vomit  \
# 2  E103    275363871   37  Female      Died   No    No   Yes    Yes   Yes
# 3  E104      2792376   45  Female      Died  Yes    No   Yes    Yes    No
# 4  E105       534008   42  Female      Died  Yes    No   Yes    Yes    No
# 5  E106       226320   22  Female      Died   No    No   Yes     No    No
# 7  E108  36563459048   45  Female      Died   No    No   Yes    Yes    No
#
#   Diarrh Weak Dizzi
# 2     No  Yes   Yes
# 3    Yes  Yes   Yes
# 4    Yes  Yes   Yes
# 5    Yes  Yes    No
# 7     No  Yes    No

# %%
sns.set(rc={'figure.figsize':(20,15)})
graph = sns.boxplot(x= "Fever", y="Age", data=data3, showfliers=False,medianprops={'linewidth': 2.5, 'color': 'yellow'} )
graph.axes.tick_params(axis='both', which='major', labelsize=30)
graph.set_xlabel("Fever", fontsize=40)
graph.set_ylabel("Age", fontsize=40)
graph.axes.set_title("Deaths Among Women Infected with Ebola Presenting with Fever as a Symptom",fontsize=40);

# %%
#export graph
graph = graph.get_figure()
graph.savefig("FemaleDeaths_FeverSymptom.jpeg")
